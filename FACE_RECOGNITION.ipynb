# %%
import cv2
import numpy as np

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces == ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face
    
cap = cv2.VideoCapture(0)
count = 0

# Collect 200 samples of your face from webcam input
while True:

    ret, photo = cap.read()
    if face_extractor(photo) is not None:
        count += 1
        face = cv2.resize(face_extractor(photo), (200, 200)) #getting the face and changing size of image
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY) #convert colour image to black-white (grayscale)

        # Save file in specified directory with unique name
        file_name_path = 'E:\ML_Projects\DataSet\\' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        pass

    if cv2.waitKey(1) == 27 or count == 200: #27 is the Esc Key
        break
        
cap.release()
cv2.destroyAllWindows() #upon completion close the window      
print("Collecting Samples Complete")
# Out:
# C:\Users\SAYANTAN\AppData\Local\Temp\ipykernel_3060\3827408232.py:13: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if faces == ():
# Collecting Samples Complete

# %%
# !python -m pip install --user opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\python39\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.3 in c:\python39\lib\site-packages (from opencv-contrib-python) (1.21.3)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: You are using pip version 21.2.3; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# model creation

# python -m pip install --user opencv-contrib-python

import cv2
import numpy as np
from os import listdir
from os.path import isfile, join
print(cv2.__version__)
# Get the training data we previously made
data_path = 'E:\ML_Projects\DataSet\\'
# a=listdir('d:/faces')
# print(a)
# """
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

# Create arrays for training data and labels
Training_Data, Labels = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles):
    image_path = data_path + onlyfiles[i]
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)
# 
# Create a numpy array for both training data and labels
Labels = np.asarray(Labels, dtype=np.int32)
# model=cv2.face_LBPHFaceRecognizer.create()

model = cv2.face.LBPHFaceRecognizer_create() 
# Initialize facial recognizer
#model = cv2.face_LBPHFaceRecognizer.create()
# model=cv2.f
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()

# Let's train our model 
model.train(np.asarray(Training_Data), np.asarray(Labels))
print("Model trained successfully")
# Out:
# 4.7.0
# Model trained successfully

# %%
#prediciton


import cv2
import numpy as np
import os
import urllib.request

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):

    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []

    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()

    image, face = face_detector(frame)

    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = model.predict(face)
        print(results)
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/400) )
            display_string = str(confidence) + '% Confident it is User'

        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)

        if confidence > 80:
           
            cv2.putText(image, "Welcome Sayantan!!", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            
            #os.system("curl /kxzehhlpr5.execute-api.ap-south-1.amazonaws.com/test/unlock")
            
            #AI MODEL
            request_url = urllib.request.urlopen("https://kxzehhlpr5.execute-api.ap-south-1.amazonaws.com/test/unlock")
            print( request_url.read())
            
            cv2.imshow('Face Recognition', image )
          

        else:
            cv2.putText(image, "i dont know", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)

            
            cv2.imshow('Face Recognition', image )

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "Locked", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass

    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# <>:16: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:16: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\SAYANTAN\AppData\Local\Temp\ipykernel_3060\4273182769.py:16: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# (167, 33.60881990891272)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (156, 35.52693132736513)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.01118709208763)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.01172189706127)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.57489216606114)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.67907824320211)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.26121055218844)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.2533657306172)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.07253048244855)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 36.18712748169832)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 36.85218605720809)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.909526091491884)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 37.119085490998614)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 36.43316591223881)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.26299087087275)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 36.18384516164386)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 36.66234329985716)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 36.7253859505317)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.76952134797809)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.619303359636504)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 32.970723531344234)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (178, 32.46225656623014)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 31.740207879478692)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 30.890686738888192)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 30.681963227816357)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 32.223159158154104)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (156, 36.98947317367511)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.81820000527956)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.275224163162335)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.35828732353805)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.45502067735547)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (19, 34.745344561426315)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (19, 35.59729186278519)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 37.13034163510102)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.77996700278028)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.174069076970916)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (19, 37.16904139910228)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 37.01030992009275)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.94242710106931)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (178, 36.36633281687227)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (178, 36.410577197926635)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (178, 36.15954571960758)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.59545100229964)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.87707062863868)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.706489242238135)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.70077957966236)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.605475039859535)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.16527458313623)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.144882978067876)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.46330994163784)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.97189035862374)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.57607996335823)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.873415985471)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 32.95527476837885)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 32.68672748450619)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.41654494243256)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.16200973741283)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.96975688677508)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 36.09626491538978)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.58359314582862)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 38.01467809647977)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (178, 35.48681195422859)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (178, 35.72497646305805)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.388223823671815)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (178, 36.218971119840866)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.220317837306474)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.816269273085375)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.257319901343266)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.1185333327748)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.658904788258)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 37.2277996683071)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.20901188869286)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.59864258091051)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.966839680252)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.21632003473111)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.12098195667958)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.51277148138174)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 33.92976467013483)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.180500270098655)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.28613934887816)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.42057027937889)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.04678601268886)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.544946075736696)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 41.05754429477565)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (26, 44.644351909312476)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (29, 49.66914779862096)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (189, 39.671369252420426)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (189, 38.33490685034995)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (178, 41.402496806430925)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 43.119938895553176)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 50.373359004137875)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 44.13076087176215)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (178, 46.17553984290038)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 50.25911016366833)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 51.41659861918244)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 54.994885727712)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 39.99668080680259)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 37.476739979258475)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 37.67695834352328)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.889880533756184)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 38.26767877960576)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 36.846353895501416)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.95892257289966)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.60002427671244)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.47832445714579)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.647843021285375)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 35.51250664700068)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (123, 99.5769849921226)
# (123, 99.5769849921226)
# (156, 59.18537343589997)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 37.270214077855016)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.5609169665043)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 41.669359768828265)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (26, 39.11948111755884)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 34.18453412392188)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 38.791835994119985)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 38.111219733272414)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 37.623854613876915)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (167, 37.294270347213626)
